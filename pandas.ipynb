# %%
import pandas as pd

data = pd.read_csv('data.csv')
print(data)
# Out:
#         name  age gender  marks        city              department
# 0        Ali   20      M     78      Lahore        Computer Science
# 1      Ahmed   21      M     85     Karachi    Software Engineering
# 2     Ayesha   19      F     88   Islamabad  Information Technology
# 3       Sara   22      F     91      Lahore        Computer Science
# 4     Hassan   20      M     67  Faisalabad  Electrical Engineering
# 5     Zainab   21      F     74      Multan  Information Technology
# 6      Usman   23      M     82  Rawalpindi    Software Engineering
# 7      Maria   20      F     90     Karachi        Computer Science
# 8    Huzaifa   22      M     69      Lahore       Civil Engineering
# 9       Iqra   19      F     95   Islamabad        Computer Science
# 10     Bilal   21      M     73      Multan  Electrical Engineering
# 11      Noor   20      F     89  Faisalabad  Information Technology
# 12      Saad   22      M     77  Rawalpindi    Software Engineering
# ...

# %%
head = data.head()
print(head)
# Out:
#      name  age gender  marks        city              department
# 0     Ali   20      M     78      Lahore        Computer Science
# 1   Ahmed   21      M     85     Karachi    Software Engineering
# 2  Ayesha   19      F     88   Islamabad  Information Technology
# 3    Sara   22      F     91      Lahore        Computer Science
# 4  Hassan   20      M     67  Faisalabad  Electrical Engineering

# %%
tail = data.tail()
print(tail)
# Out:
#         name  age gender  marks       city              department
# 15     Laiba   20      F     92  Islamabad        Computer Science
# 16     Adnan   24      M     66     Multan  Electrical Engineering
# 17     Maham   19      F     87     Lahore  Information Technology
# 18  Shahzaib   22      M     80    Karachi    Software Engineering
# 19      Anum   21      F     93  Islamabad        Computer Science

# %%
info = data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        20 non-null     object
#  1   age         20 non-null     int64
#  2   gender      20 non-null     object
#  3   marks       20 non-null     int64
#  4   city        20 non-null     object
#  5   department  20 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 1.1+ KB

# %%
describe = data.describe()
print(describe)
# Out:
#              age      marks
# count  20.000000  20.000000
# mean   21.000000  81.550000
# std     1.414214   9.219402
# min    19.000000  66.000000
# 25%    20.000000  73.750000
# 50%    21.000000  83.000000
# 75%    22.000000  89.250000
# max    24.000000  95.000000

# %%
mydictionary = [{
    "name":"Azan",
    "age":20,
    "city":"New York",
    "work":["english teacher","developer","designer"]
},{
    "name":"John",
    "age":22,
    "city":"London",
    "work":["doctor","engineer","artist"]
}]


df = pd.DataFrame(mydictionary)
print(df)
# Out:
#    name  age      city                                    work
# 0  Azan   20  New York  [english teacher, developer, designer]
# 1  John   22    London              [doctor, engineer, artist]
